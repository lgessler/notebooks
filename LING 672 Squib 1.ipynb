# %%
import torch
import hypertools
# %matplotlib widget
import matplotlib.pyplot as plt

# Initialize BERT and some helper functions
BERT_MODEL = "bert-base-cased"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/luke/.anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# use allennlp's bert wrappers, which handle the wordpiece tokenization nastiness 
# and let us get a single vector per input token. don't worry about the rest of this cell
from transformers import BertTokenizer
from allennlp.data import Vocabulary, Token
from allennlp.data.token_indexers import PretrainedTransformerMismatchedIndexer
from allennlp.modules.token_embedders import PretrainedTransformerMismatchedEmbedder
tokenizer = BertTokenizer.from_pretrained(BERT_MODEL)
indexer = PretrainedTransformerMismatchedIndexer(model_name=BERT_MODEL, namespace="tokens")
vocab = Vocabulary()
for word in tokenizer.vocab.keys():
    vocab.add_token_to_namespace("tokens")
embedder = PretrainedTransformerMismatchedEmbedder(model_name=BERT_MODEL).eval().to(DEVICE)

# %%
def encode_sentence(sentence):
    """Given a list of tokens or a string of length m, return a tensor of embeddings 
    with shape (m, N), where N is 768 for bert base"""
    with torch.no_grad():
        if isinstance(sentence, str):
            sentence = sentence.split()
        inputs = indexer.tokens_to_indices([Token(text=token) for token in sentence], vocab)
        for key, value in inputs.items():
            inputs[key] = torch.tensor([value], device=DEVICE)
        tensor = embedder(**inputs)
        return tensor[0]
    
tensor = encode_sentence(['Hello', ',', 'world', '!'])
print(tensor)
print(tensor.shape)
# Out:
# tensor([[ 0.4953, -0.2757,  0.8327,  ..., -0.3281,  0.4333, -0.1131],
#         [ 0.4680,  0.3816,  0.5320,  ..., -0.0647, -0.1558, -0.1061],
#         [ 0.4916,  0.2297,  0.3994,  ..., -0.3129, -0.3210, -0.3038],
#         [ 0.5205,  0.2332,  0.8453,  ...,  0.2023,  0.3757,  0.1231]],
#        device='cuda:0')
# torch.Size([4, 768])

# %%
from nltk.corpus import framenet as fn
from tqdm.notebook import tqdm
import nltk
print(nltk.__file__)
frames = fn.frames()

# see: https://github.com/nltk/nltk/issues/2616
annotations = []
progress = tqdm(total=400000)
try:
    for annotation in fn.annotations():
        annotations.append(annotation)
        progress.update(1)
except RuntimeError as e:
    print("Exception!", e)
finally:
    print(len(annotations))
progress.close()
# Out:
# /home/luke/.anaconda3/lib/python3.7/site-packages/nltk/__init__.py
# HBox(children=(IntProgress(value=0, max=400000), HTML(value='')))
# 229692

# %%
#print(frame)
#lexical_unit = frame.lexUnit['abandon.v']
#print(lexical_unit)
#print([x for x in dir(fn) if not x.startswith("_")])

def slice2index(text, slice_):
    begin, end = slice_
    target_word = text[begin:end]
    tokens = text.split()
    token_index = 0
    i = 0
    while i < len(text):
        token = tokens[token_index]
        if i == begin and token.lower() == target_word.lower():
            if end - begin != len(token):
                print(f"ERROR: word '{token}' is {len(token)} chars long, but FrameNet said it was {j-1} chars long")
            return token_index
        else:
            i += len(token) + 1
            token_index += 1
    raise Exception(f"Word not found!\nLooked for {target_word}, but couldn't find it in {tokens}")
        
        
def target_vector(annotation):
    text, targets = annotation.text, annotation.Target
    tokens = text.split()
    target_indexes = [slice2index(text, target_slice) for target_slice in targets]
    
    tensor = encode_sentence(tokens)
    # make sure allennlp bert kept its promise
    assert len(tokens) == tensor.shape[0]
    
    # for multi-word targets, take their average
    target_vector = torch.mean(torch.stack([tensor[i] for i in target_indexes][:1]), dim=0)
    return target_vector

# %%
import os, pickle
def get_vectors(annotations):
    vectors = []
    
    path = 'vecs.pkl'
    if os.path.isfile(path):
        print("Loading from pickle")
        with open(path, 'rb') as f:
            vectors = pickle.load(f)
        
    def handle_annotation(annotation):
        try:
            if "Target" not in annotation:
                print(f"{i}: Skipping targetless ann")
                return
            if "frame" not in annotation:
                print(f"{i}: Skipping frameless ann")
                return
            vectors.append(target_vector(annotation))
        except Exception as e:
            print(type(annotation))
            print(annotation.keys())
            print("Uh oh!")
            print(e)
            vectors.append(None)
            
    i = len(vectors)
    any_new = False
    progress = tqdm(total=len(annotations))
    progress.update(len(vectors))
    while i < len(annotations):
        handle_annotation(annotations[i])
        progress.update(1)
        any_new = True
        i += 1
    progress.close()
    
    if any_new:
        with open(path, 'wb') as f:
            print("Writing pickle")
            pickle.dump(vectors, f)
    
    return vectors

vectors = get_vectors(annotations)
len(vectors), len(annotations)
# Out:
# HBox(children=(IntProgress(value=0, max=229692), HTML(value='')))
# 2560: Skipping targetless ann
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'also', 'has', 'split', 'with', 'the', 'left', 'in', 'reaffirming', 'Spain', "'s", 'NATO', 'commitment', 'and', 'in', 'renewing', 'a', 'defense', 'treaty', 'with', 'the', 'U.S', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'is', 'not', 'quite', 'a', 'closet', 'supply-side', 'revolutionary', ',', 'however', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['The', 'voters', 'delivered', 'Mr.', 'Gonzalez', 'a', 'third', 'mandate', 'for', 'his', 'successes', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['It', 'would', 'be', 'sad', 'for', 'Mr.', 'Gonzalez', 'to', 'abandon', 'them', 'to', 'appease', 'his', 'foes', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'and', 'his', 'colleagues', ',', 'particularly', 'the', 'finance', 'minister', ',', 'Carlos', 'Solchaga', ',', 'are', 'charged', 'with', 'having', 'abandoned', 'their', 'socialist', 'principles', 'and', 'with', 'having', 'become', 'arrogant', 'elitists', 'who', 'refuse', 'even', 'to', 'go', 'on', 'television', '(', 'controlled', 'by', 'the', 'state', ')', 'to', 'face', 'their', 'accusers', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for appeared, but couldn't find it in ['For', 'once', 'the', 'NFL', 'schedule-makers', 'appeared..']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'FE2', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for appeared, but couldn't find it in ['I', 'called', 'up', 'the', 'synonyms', 'for', 'the', 'adj', 'and', 'the', 'following', 'appeared:']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for job, but couldn't find it in ['I', 'really', 'like', 'my', 'job.', "''", '--', 'Sherry']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Control, but couldn't find it in ['Effects', 'of', 'Lay', 'Theories', 'of', 'Self-Control', 'on', 'Setting', 'and', 'Keeping', 'Resolutions', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for name, but couldn't find it in ['Once', 'it', 'seemed', 'that', 'the', 'nonsensical', 'blather', 'of', 'a', 'song', 'like', 'America', "'s", '``', 'Horse', 'With', 'No', 'Name', "''", '(', 'with', 'the', 'immortal', 'lines', '``', 'The', 'heat', 'was', 'hot', "''", 'and', '``', 'In', 'the', 'desert/', 'You', 'ca', "n't", 'remember', 'your', 'name/', "'Cause", 'there', 'ai', "n't", 'no', 'one/', 'For', 'to', 'give', 'you', 'no', 'pain', "''", ')', 'could', 'never', 'be', 'challenged', 'by', 'any', 'rival', 'in', 'any', 'other', 'art', 'form', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for carried, but couldn't find it in ['In', 'a', 'sort', 'of', 'dream', 'I', 'remember', 'being', 'half-led', ',', 'halfcarried', 'to', 'the', 'carriage', ';', 'in', 'the', 'same', 'state', 'I', 'was', 'conveyed', 'to', 'the', 'train', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Levels, but couldn't find it in ['Take', 'the', 'Mid-Levels', 'Escalator', 'to', 'Hollywood', 'road', ',', 'known', 'for', 'its', 'antiques', 'and', 'curio', 'shopping', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Levels, but couldn't find it in ['Hollywood', 'Road', 'in', 'the', 'Mid-Levels', 'above', 'Central', 'is', 'the', 'most', 'famous', 'antiques', 'street', 'in', 'Hong', 'Kong', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Levels, but couldn't find it in ['It', 'ferries', 'commuters', 'from', 'the', 'Mid-Levels', 'apartment', 'complexes', 'downhill', 'from', '6', 'to', '10am', ',', 'and', 'uphill', 'from', '10am', 'to', 'midnight', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Monday, but couldn't find it in ['A', 'large', 'forest', 'fire', 'that', 'started', 'on', 'Monday,', 'June', '9', 'is', 'still', 'out', 'of', 'control', 'in', 'the', 'municipality', 'of', 'Froland', 'in', 'southern', 'Norway', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for era, but couldn't find it in ['(', 'NYT_ENG', '_20130625.0044', ')', 'Meanwhile', ',', 'in', 'Pretoria', ',', 'doctors', 'continued', 'to', 'treat', 'Mandela', 'for', 'a', 'lung', 'ailment', 'that', 'he', 'contracted', 'on', 'Robben', 'Island', ',', 'the', 'notorious', 'apartheid-era', 'prison', 'where', 'he', 'spent', 'much', 'of', 'his', '27', 'years', 'behind', 'bars', 'until', 'his', 'release', 'in', '1990', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'FE2', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for five, but couldn't find it in ['Almost', 'half', 'of', 'Ireland', "'s", 'population', 'is', 'under', 'twenty-five', ',', 'and', 'with', 'its', 'universities', 'and', 'professional', 'schools', ',', 'Dublin', 'also', 'has', 'a', 'large', 'student', 'population', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'FE2', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for twenty, but couldn't find it in ['Almost', 'half', 'of', 'Ireland', "'s", 'population', 'is', 'under', 'twenty-five', ',', 'and', 'with', 'its', 'universities', 'and', 'professional', 'schools', ',', 'Dublin', 'also', 'has', 'a', 'large', 'student', 'population', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for gray, but couldn't find it in ['He', 'is', 'a', 'man', 'of', 'fifty', ',', 'strong', ',', 'active', ',', 'with', 'iron-gray', 'hair', ',', 'great', 'bunched', 'black', 'eyebrows', ',', 'the', 'step', 'of', 'a', 'deer', 'and', 'the', 'air', 'of', 'an', 'emperor', '-', 'a', 'fierce', ',', 'masterful', 'man', ',', 'with', 'a', 'red-hot', 'spirit', 'behind', 'his', 'parchment', 'face', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for coloured, but couldn't find it in ['The', 'curved', 'and', 'shadowed', 'drive', 'led', 'us', 'to', 'a', 'low', ',', 'dark', 'house', ',', 'pitchblack', 'against', 'a', 'slate-coloured', 'sky', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Fool, but couldn't find it in ['The', 'attack', ',', 'medical', 'personnel', 'and', 'volunteer', '``', 'patients', "''", 'were', 'told', ',', 'occurred', 'at', 'a', 'mythical', 'April', "Fool's", 'Day', 'parade', 'in', 'Dublin', ',', 'said', 'Laurice', 'Bentley', ',', 'risk', 'communication', 'specialist', 'for', 'the', 'South', 'Central', 'Health', 'District', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Fool, but couldn't find it in ['The', 'attack', ',', 'medical', 'personnel', 'and', 'volunteer', '``', 'patients', "''", 'were', 'told', ',', 'occurred', 'at', 'a', 'mythical', 'April', "Fool's", 'Day', 'parade', 'in', 'Dublin', ',', 'said', 'Laurice', 'Bentley', ',', 'risk', 'communication', 'specialist', 'for', 'the', 'South', 'Central', 'Health', 'District', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Sold, but couldn't find it in ["'Sold", 'his', 'soul', 'to', 'the', 'devil', 'in', 'exchange', 'for', 'money', ',', "'", 'says', 'Warner', ',', "'and", 'expects', 'his', 'creditor', 'to', 'come', 'up', 'and', 'claim', 'his', 'own', '.', "'"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for laments, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adv', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for so far, but couldn't find it in ['Four', 'people', 'have', 'perished', 'so', 'far', 'in', 'the', 'blazes', 'which', 'the', 'government', 'says', 'were', 'started', 'intentionally', 'by', 'arsonists', 'over', 'a', 'week', 'ago', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adj', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for True, but couldn't find it in ['True..']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for led, but couldn't find it in ['In', 'a', 'sort', 'of', 'dream', 'I', 'remember', 'being', 'half-led', ',', 'halfcarried', 'to', 'the', 'carriage', ';', 'in', 'the', 'same', 'state', 'I', 'was', 'conveyed', 'to', 'the', 'train', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for defence, but couldn't find it in ['"', 'A', 'plausible', 'lawyer', 'could', 'make', 'it', 'out', 'as', 'an', 'act', 'of', 'self-defence', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for defence, but couldn't find it in ['Self-defence', 'is', 'one', 'thing', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adj', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for poor, but couldn't find it in ['The', 'robustness', 'of', 'ROC', 'analysis', 'to', 'yield', 'T', 'M', 'and', 'ROC', 'area', 'values', 'to', 'discriminate', "'good", "'", 'from', "'poor", "'", 'microarray', 'hybridizations', 'relies', 'on', 'the', 'relative', 'positions', 'of', 'signal', 'ranges', 'from', 'positive', 'and', 'negative', 'controls', 'as', 'well', 'as', 'from', 'target', 'genes', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['Landing', 'on', 'the', 'beach', 'at', 'Barra', 'is', 'a', 'piece', 'of', 'cake', 'for', 'Captain', 'Bob', 'Macleod', ',', 'the', 'experienced', 'Loganair', 'pilot', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['After', 'that', ',', 'even', 'flambeeing', 'the', 'Escalope', 'de', 'Dinde', 'Vieille', 'Henriette', 'was', 'a', 'piece', 'of', 'cake', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['Then', 'I', 'repeated', 'the', 'oft', 'cried', 'lie', ',', '‘', 'Climb', 'when', 'you', "'re", 'ready', 'Ben', '…', 'it', "'s", 'a', 'piece', 'of', 'cake', '!', '’']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['At', 'first', 'he', 'kept', 'saying', 'that', 'housekeeping', 'was', 'a', 'piece', 'of', 'cake', 'and', 'that', 'women', 'made', 'a', 'big', 'fuss', 'about', 'nothing', 'but', 'since', 'the', 'washing', 'machine', 'broke', 'down', 'he', 'has', "n't", 'said', 'that', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['It', "'s", 'a', 'piece', 'of', 'cake', '?', 'Jim', 'Makin', ',', 'Bill', 'Mellor', ',', 'Michael', 'Hardman', 'and', 'Graham', 'Lees', 'celebrate', 'the', 'first', '10', 'years', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['My', 'bone', 'marrow', 'was', 'harvested', 'a', 'couple', 'of', 'weeks', 'ago', 'and', 'the', 'whole', 'thing', 'was', 'a', 'piece', 'of', 'cake', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['Normally', ',', 'walking', 'along', 'tarmac', 'is', 'a', 'piece', 'of', 'cake', 'after', 'the', 'rocky', 'excursion', 'along', 'a', 'ridge', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['He', 'had', 'a', 'premonition', 'that', 'providing', 'an', 'ear', 'would', 'be', 'a', 'piece', 'of', 'cake', ';', 'it', 'was', 'the', 'something', 'else', 'which', 'was', 'likely', 'to', 'prove', 'complicated', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['I', 'had', 'located', 'the', 'dreaded', 'Carol', 'easily', 'enough', 'and', 'reclaiming', 'the', 'pendant', 'had', 'been', 'a', 'piece', 'of', 'cake', ',', 'well', ',', 'a', 'piece', 'of', 'more', 'than', 'cake', ',', 'actually', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['Sometimes', 'Bessie', 'would', 'come', 'up', 'to', 'me', 'in', 'my', 'lonely', 'bedroom', ',', 'bringing', 'a', 'piece', 'of', 'cake', ',', 'sometimes', 'she', 'would', 'tell', 'me', 'a', 'story', ',', 'and', 'sometimes', 'she', 'would', 'kiss', 'me', 'good', 'night', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['The', 'Mac', 'may', 'be', 'indispensable', 'for', 'the', 'process', 'of', 'design', 'work', ',', 'but', 'there', 'is', 'a', 'dangerous', 'temptation', 'to', 'think', 'that', 'desktop', 'publishing', 'makes', 'designing', 'on', 'screen', 'a', 'piece', 'of', 'cake', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['But', 'there', 'is', 'no', 'use', 'pretending', 'the', 'Saturn-Pluto', 'effect', 'will', 'be', 'a', 'piece', 'of', 'cake', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for piece , but couldn't find it in ['The', 'one', 'he', 'was', 'allocated', ',', 'Parky', ',', 'a', 'homely', ',', 'Hoomey-sized', 'bay', ',', 'was', 'a', 'piece', 'of', 'cake', 'compared', 'with', 'Bones', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Adj', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adj', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for long, but couldn't find it in ['Just', 'up', 'a', 'lane', 'from', 'the', 'market', 'is', 'the', 'Man', 'Mo', 'Temple', ',', 'with', 'long-burning', 'incense', 'coils', 'hanging', 'from', 'its', 'ceiling', ',', 'a', 'popular', 'spot', 'dedicated', 'to', 'the', 'Taoist', 'gods', 'of', 'war', 'and', 'literature', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for put, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the slip, but couldn't find it in ['Police', 'investigations', 'showed', 'the', 'unidentified', 'victim', 'was', 'among', 'four', 'of', 'six', 'men', 'who', 'gave', 'police', 'the', 'slip', 'at', 'a', 'roadblock', 'in', 'Gua', 'Musang', 'on', 'Jan', '30', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the slip, but couldn't find it in ['Police', 'were', 'given', 'the', 'slip', 'during', 'the', 'night', 'but', 'the', 'Porsche', 'was', 'sighted', 'again', 'Monday', 'morning', 'near', 'Diepholz', ',', 'about', '140', 'kilometers', '(', '87', 'miles', ')', 'west', 'of', 'Celle', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the slip, but couldn't find it in ['PARIS', '(', 'AP', ')', '---', 'French', 'authorities', 'trying', 'to', 'catch', 'a', 'terrorist', 'bomber', 'are', 'coming', 'to', 'grips', 'with', 'an', 'unpleasant', 'thought', '---', 'their', 'No.', '1', 'suspect', 'may', 'have', 'quietly', 'given', 'them', 'the', 'slip', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the slip, but couldn't find it in ['Cooper', 'said', 'all', 'five', 'had', 'arrived', 'in', 'Doha', 'on', 'tourist', 'visas', 'arranged', 'by', 'hotels', ',', 'but', 'they', 'switched', 'hotels', 'in', 'an', 'effort', 'to', 'give', 'security', 'officials', 'the', 'slip', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the s, but couldn't find it in ['Sometimes', 'we', 'have', 'to', 'give', 'the', 'officials', 'the', 'slip', 'so', 'that', 'we', 'can', 'go', 'out', 'to', 'fish', ',', "''", 'Samala', 'said', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for the slip, but couldn't find it in ['Kerry', 'gave', 'them', 'the', 'slip', 'and', 'was', 'found', 'Sunday', 'night', 'in', 'Kota', 'Bahru', ',', '400', 'kilometers', '(', '250', 'miles', ')', 'north', 'of', 'the', 'capital', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['Nothing', 'that', 'rang', 'a', 'bell', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for rin, but couldn't find it in ['Somehow', 'it', 'rings', 'a', 'bell', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['It', 'rang', 'a', 'bell', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['`', 'Does', 'any', 'of', 'it', 'ring', 'a', 'bell', '?']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['Does', 'it', 'ring', 'a', 'bell', '?', '"']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['To', 'readers', 'of', 'this', 'column', 'does', 'the', 'name', 'Rosenstein', 'ring', 'a', 'bell', '?']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for traces, but couldn't find it in ['1.', 'visual', 'analysis', 'of', 'raw', 'EEG', 'traces,']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for ve, but couldn't find it in ['Now', 'when', 'the', 'wind', 'howls', 'and', 'you', "'ve", 'got', 'palm', 'trees', 'and', 'eucalyptus', 'trees', 'that', 'are', 'literally', 'exploding', 'with', 'their', 'hot', 'oil', ',', 'you', "'ve", 'got', 'these', 'big', ',', 'red', 'hot', 'embers', 'that', 'are', 'flying', 'through', 'the', 'sky', 'and', 'are', 'catching', 'anything', 'on', 'fire', '.', "''"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for eaten, but couldn't find it in ['The', 'table', 'was', 'piled', 'with', 'half-eaten', 'dishes', 'and', 'dirty', 'plates', ',', 'the', 'debris', 'of', 'last', 'night', "'s", 'dinner', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for did, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for , but couldn't find it in ['Landlords', 'are', 'taken', 'to', 'task', 'over', 'standards']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for al S, but couldn't find it in ['Irwin', 'Gabathuler', 'of', 'the', 'University', 'of', 'Liverpool', 'took', 'theorists', 'to', 'task', 'at', 'a', 'meeting', 'at', 'the', 'Royal', 'Society', 'in', 'London', 'last', 'month', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'FE', 'GF', 'PT', 'Sent', 'Other', 'Target', 'Verb', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for police, but couldn't find it in ['This', 'is', 'not', 'talk', 'for', 'a', 'police-constable', '.', '"']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for fire departments, but couldn't find it in ['Local', 'fire', 'departments', 'put', 'the', 'current', 'death', 'toll', 'at', 'at', 'least', '37', ',', 'nine', 'of', 'which', 'were', 'children', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Fire department, but couldn't find it in ['Fire', 'department', 'spokesman', 'Nikos', 'Diamandis', 'said', 'most', 'of', 'the', 'fires', 'were', 'started', 'in', 'entirely', 'different', 'areas', ',', 'and', 'were', 'started', 'after', 'dark', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Prime Minister, but couldn't find it in ['Prime', 'Minister', 'Costas', 'Karamanlis', 'was', 'to', 'for', 'an', 'emergency', 'meeting', 'of', 'the', 'senior', 'ministers', 'in', 'the', 'country', "'s", 'capital', ',', 'Athens', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for Traces, but couldn't find it in ['The', 'award-winning', 'illustrated', 'history', 'magazine', '-Traces', 'of', 'Indiana', 'and', 'Midwestern', 'History', ';', 'the', 'scholarly', 'journal-', 'Indiana', 'Magazine', 'of', 'History', ';', 'the', 'family', 'history', 'publication', '-The', 'Hoosier', 'Genealogist', ';', 'and', 'the', 'Hoosier', 'African-American', 'history', 'newsletter-', 'Black', 'History', 'News', 'MYAMP', 'amp', ';', 'Notes', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# list index out of range
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adj', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for dark, but couldn't find it in ['Mice', 'were', 'killed', 'between', '2', 'p.m.', 'and', '4', 'p.m.', ',', 'and', 'were', 'housed', 'on', 'a', '12:12', 'light:dark', 'cycle', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for function, but couldn't find it in ['The', 'e-vector', '(', 'heading', ')', 'returned', 'from', 'the', 'two', 'polarization-sensitive', 'photodiodes', '(', '1', ',', '2', ')', 'follows', 'a', 'cos2-function', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for mile, but couldn't find it in ['Place', 'names', 'are', 'often', 'based', 'on', 'the', 'distance', 'to', 'the', 'nearest', 'mile-post', ',', 'as', 'measured', 'from', 'the', 'tip', 'of', 'the', 'Kowloon', 'peninsula', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for sense, but couldn't find it in ['simply', 'does', 'not', 'make', 'any', 'sense.', 'The']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for side, but couldn't find it in ['Everything', 'is', 'sold', 'here', ',', 'from', 'clothing', 'to', 'souvenirs', 'to', 'electronic', 'goods', ',', 'and', 'the', 'market', 'is', 'known', 'for', 'its', 'street-side', 'food', 'stalls', ',', 'where', 'you', 'can', 'dine', 'inexpensively', 'on', 'seafood', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for man, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for fire fighters, but couldn't find it in ['Commissioner', 'of', 'the', 'NSW', 'Rural', 'Fire', 'Service', 'said', 'fire', 'fighters', 'had', 'made', 'a', 'brave', 'effort', 'to', 'contain', 'the', 'fire', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for fire fighters, but couldn't find it in ['With', 'temperatures', 'in', 'the', 'high', '30', 'degree', 'Celsius', 'range', 'and', 'winds', 'around', '50', 'km/h', '(', '31', 'Mph', ')', ',', 'fire', 'fighters', 'are', 'bracing', 'for', 'the', 'worst', 'in', 'the', 'Blue', 'Mountains', 'over', 'the', 'next', 'few', 'days', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for fire, but couldn't find it in ['Approximately', '140', 'persons', ',', 'including', 'fire-fighters', 'from', 'several', 'fire', 'departments', ',', 'and', 'personnel', 'from', 'the', 'Civil', 'Defence', 'and', 'the', 'Home', 'Guard', 'are', 'working', 'to', 'curtail', 'the', 'fire', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for country, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for State, but couldn't find it in ['Name', 'Address', 'City', ',', 'State,', 'Zip']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for mess, but couldn't find it in ['Simply', 'put', ',', 'Stephanopoulos', 'did', 'as', 'much', 'as', 'any', 'man', 'to', 'get', 'the', 'country', 'into', 'the', 'mess', 'he', 'now', 'so', 'telegenically', 'laments', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'sent', 'text', 'LU', 'frame'])
# Uh oh!
# Word not found!
# Looked for level, but couldn't find it in ['The', 'analysis', 'confirms—and', 'extends', 'to', 'a', 'global', 'level—previous', 'research', 'showing', 'that', 'many', 'major', 'health', 'risks', 'are', 'important', 'across', 'the', 'range', 'of', 'exposure', 'levels', ',', 'not', 'just', 'among', 'individuals', 'exposed', 'to', 'high', 'levels', 'of', 'risk', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# ...
# Uh oh!
# Word not found!
# Looked for long, but couldn't find it in ['Just', 'up', 'a', 'lane', 'from', 'the', 'market', 'is', 'the', 'Man', 'Mo', 'Temple', ',', 'with', 'long-burning', 'incense', 'coils', 'hanging', 'from', 'its', 'ceiling', ',', 'a', 'popular', 'spot', 'dedicated', 'to', 'the', 'Taoist', 'gods', 'of', 'war', 'and', 'literature', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Fool, but couldn't find it in ['The', 'attack', ',', 'medical', 'personnel', 'and', 'volunteer', '``', 'patients', "''", 'were', 'told', ',', 'occurred', 'at', 'a', 'mythical', 'April', "Fool's", 'Day', 'parade', 'in', 'Dublin', ',', 'said', 'Laurice', 'Bentley', ',', 'risk', 'communication', 'specialist', 'for', 'the', 'South', 'Central', 'Health', 'District', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for fire fighters, but couldn't find it in ['Commissioner', 'of', 'the', 'NSW', 'Rural', 'Fire', 'Service', 'said', 'fire', 'fighters', 'had', 'made', 'a', 'brave', 'effort', 'to', 'contain', 'the', 'fire', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for fire fighters, but couldn't find it in ['With', 'temperatures', 'in', 'the', 'high', '30', 'degree', 'Celsius', 'range', 'and', 'winds', 'around', '50', 'km/h', '(', '31', 'Mph', ')', ',', 'fire', 'fighters', 'are', 'bracing', 'for', 'the', 'worst', 'in', 'the', 'Blue', 'Mountains', 'over', 'the', 'next', 'few', 'days', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Adv', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for so far, but couldn't find it in ['Four', 'people', 'have', 'perished', 'so', 'far', 'in', 'the', 'blazes', 'which', 'the', 'government', 'says', 'were', 'started', 'intentionally', 'by', 'arsonists', 'over', 'a', 'week', 'ago', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for ve, but couldn't find it in ['Now', 'when', 'the', 'wind', 'howls', 'and', 'you', "'ve", 'got', 'palm', 'trees', 'and', 'eucalyptus', 'trees', 'that', 'are', 'literally', 'exploding', 'with', 'their', 'hot', 'oil', ',', 'you', "'ve", 'got', 'these', 'big', ',', 'red', 'hot', 'embers', 'that', 'are', 'flying', 'through', 'the', 'sky', 'and', 'are', 'catching', 'anything', 'on', 'fire', '.', "''"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for ve, but couldn't find it in ['Now', 'when', 'the', 'wind', 'howls', 'and', 'you', "'ve", 'got', 'palm', 'trees', 'and', 'eucalyptus', 'trees', 'that', 'are', 'literally', 'exploding', 'with', 'their', 'hot', 'oil', ',', 'you', "'ve", 'got', 'these', 'big', ',', 'red', 'hot', 'embers', 'that', 'are', 'flying', 'through', 'the', 'sky', 'and', 'are', 'catching', 'anything', 'on', 'fire', '.', "''"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for on fire, but couldn't find it in ['Now', 'when', 'the', 'wind', 'howls', 'and', 'you', "'ve", 'got', 'palm', 'trees', 'and', 'eucalyptus', 'trees', 'that', 'are', 'literally', 'exploding', 'with', 'their', 'hot', 'oil', ',', 'you', "'ve", 'got', 'these', 'big', ',', 'red', 'hot', 'embers', 'that', 'are', 'flying', 'through', 'the', 'sky', 'and', 'are', 'catching', 'anything', 'on', 'fire', '.', "''"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for fire departments, but couldn't find it in ['Local', 'fire', 'departments', 'put', 'the', 'current', 'death', 'toll', 'at', 'at', 'least', '37', ',', 'nine', 'of', 'which', 'were', 'children', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Fire department, but couldn't find it in ['Fire', 'department', 'spokesman', 'Nikos', 'Diamandis', 'said', 'most', 'of', 'the', 'fires', 'were', 'started', 'in', 'entirely', 'different', 'areas', ',', 'and', 'were', 'started', 'after', 'dark', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Prime Minister, but couldn't find it in ['Prime', 'Minister', 'Costas', 'Karamanlis', 'was', 'to', 'for', 'an', 'emergency', 'meeting', 'of', 'the', 'senior', 'ministers', 'in', 'the', 'country', "'s", 'capital', ',', 'Athens', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Monday, but couldn't find it in ['A', 'large', 'forest', 'fire', 'that', 'started', 'on', 'Monday,', 'June', '9', 'is', 'still', 'out', 'of', 'control', 'in', 'the', 'municipality', 'of', 'Froland', 'in', 'southern', 'Norway', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for fire, but couldn't find it in ['Approximately', '140', 'persons', ',', 'including', 'fire-fighters', 'from', 'several', 'fire', 'departments', ',', 'and', 'personnel', 'from', 'the', 'Civil', 'Defence', 'and', 'the', 'Home', 'Guard', 'are', 'working', 'to', 'curtail', 'the', 'fire', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for fire, but couldn't find it in ['Approximately', '140', 'persons', ',', 'including', 'fire-fighters', 'from', 'several', 'fire', 'departments', ',', 'and', 'personnel', 'from', 'the', 'Civil', 'Defence', 'and', 'the', 'Home', 'Guard', 'are', 'working', 'to', 'curtail', 'the', 'fire', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for coloured, but couldn't find it in ['The', 'curved', 'and', 'shadowed', 'drive', 'led', 'us', 'to', 'a', 'low', ',', 'dark', 'house', ',', 'pitchblack', 'against', 'a', 'slate-coloured', 'sky', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for police, but couldn't find it in ['This', 'is', 'not', 'talk', 'for', 'a', 'police-constable', '.', '"']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for eaten, but couldn't find it in ['The', 'table', 'was', 'piled', 'with', 'half-eaten', 'dishes', 'and', 'dirty', 'plates', ',', 'the', 'debris', 'of', 'last', 'night', "'s", 'dinner', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for gray, but couldn't find it in ['He', 'is', 'a', 'man', 'of', 'fifty', ',', 'strong', ',', 'active', ',', 'with', 'iron-gray', 'hair', ',', 'great', 'bunched', 'black', 'eyebrows', ',', 'the', 'step', 'of', 'a', 'deer', 'and', 'the', 'air', 'of', 'an', 'emperor', '-', 'a', 'fierce', ',', 'masterful', 'man', ',', 'with', 'a', 'red-hot', 'spirit', 'behind', 'his', 'parchment', 'face', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Sold, but couldn't find it in ["'Sold", 'his', 'soul', 'to', 'the', 'devil', 'in', 'exchange', 'for', 'money', ',', "'", 'says', 'Warner', ',', "'and", 'expects', 'his', 'creditor', 'to', 'come', 'up', 'and', 'claim', 'his', 'own', '.', "'"]
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for led, but couldn't find it in ['In', 'a', 'sort', 'of', 'dream', 'I', 'remember', 'being', 'half-led', ',', 'halfcarried', 'to', 'the', 'carriage', ';', 'in', 'the', 'same', 'state', 'I', 'was', 'conveyed', 'to', 'the', 'train', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for carried, but couldn't find it in ['In', 'a', 'sort', 'of', 'dream', 'I', 'remember', 'being', 'half-led', ',', 'halfcarried', 'to', 'the', 'carriage', ';', 'in', 'the', 'same', 'state', 'I', 'was', 'conveyed', 'to', 'the', 'train', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for defence, but couldn't find it in ['"', 'A', 'plausible', 'lawyer', 'could', 'make', 'it', 'out', 'as', 'an', 'act', 'of', 'self-defence', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for defence, but couldn't find it in ['Self-defence', 'is', 'one', 'thing', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for developed, but couldn't find it in ['It', 'covers', 'two', 'continents', ',', 'concerns', 'two', 'groups', 'of', 'mysterious', 'persons', ',', 'and', 'is', 'further', 'complicated', 'by', 'the', 'highly', 'respectable', 'presence', 'of', 'our', 'friend', ',', 'Scott', 'Eccles', ',', 'whose', 'inclusion', 'shows', 'me', 'that', 'the', 'deceased', 'Garcia', 'had', 'a', 'scheming', 'mind', 'and', 'a', 'well-developed', 'instinct', 'of', 'selfpreservation', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for era, but couldn't find it in ['(', 'NYT_ENG', '_20130625.0044', ')', 'Meanwhile', ',', 'in', 'Pretoria', ',', 'doctors', 'continued', 'to', 'treat', 'Mandela', 'for', 'a', 'lung', 'ailment', 'that', 'he', 'contracted', 'on', 'Robben', 'Island', ',', 'the', 'notorious', 'apartheid-era', 'prison', 'where', 'he', 'spent', 'much', 'of', 'his', '27', 'years', 'behind', 'bars', 'until', 'his', 'release', 'in', '1990', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'and', 'his', 'colleagues', ',', 'particularly', 'the', 'finance', 'minister', ',', 'Carlos', 'Solchaga', ',', 'are', 'charged', 'with', 'having', 'abandoned', 'their', 'socialist', 'principles', 'and', 'with', 'having', 'become', 'arrogant', 'elitists', 'who', 'refuse', 'even', 'to', 'go', 'on', 'television', '(', 'controlled', 'by', 'the', 'state', ')', 'to', 'face', 'their', 'accusers', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'also', 'has', 'split', 'with', 'the', 'left', 'in', 'reaffirming', 'Spain', "'s", 'NATO', 'commitment', 'and', 'in', 'renewing', 'a', 'defense', 'treaty', 'with', 'the', 'U.S', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['Mr.', 'Gonzalez', 'is', 'not', 'quite', 'a', 'closet', 'supply-side', 'revolutionary', ',', 'however', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['The', 'voters', 'delivered', 'Mr.', 'Gonzalez', 'a', 'third', 'mandate', 'for', 'his', 'successes', '.']
# <class 'nltk.corpus.reader.framenet.AttrDict'>
# dict_keys(['cDate', 'luID', 'luName', 'frameID', 'frameName', 'status', 'ID', '_type', 'layer', '_ascii', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Noun', 'LU', 'frame', 'sent', 'text'])
# Uh oh!
# Word not found!
# Looked for Mr, but couldn't find it in ['It', 'would', 'be', 'sad', 'for', 'Mr.', 'Gonzalez', 'to', 'abandon', 'them', 'to', 'appease', 'his', 'foes', '.']
#
# Writing pickle
# (229691, 229692)

# %%
from collections import defaultdict
frame2pairs = defaultdict(list)
parent2children = defaultdict(list)

skipped = 0
for i, (vector, annotation) in tqdm(enumerate(zip(vectors, annotations)), total=len(annotations)):
    if vector is None:
        print(f"Skipping none vector at {i}", end='\r')
        skipped += 1
        continue
        
    frame = annotation.frame
    frame_name = frame.name
    frame2pairs[frame_name].append((vector.to('cpu'), annotation))
    for relation in frame.frameRelations:
        if relation.type.name == 'Inheritance':
            child_name = relation.Child.name
            parent_name = relation.Parent.name
            if child_name not in parent2children[parent_name]:
                parent2children[parent_name].append(child_name)
print(f"Skipped {skipped}")
# Out:
# HBox(children=(IntProgress(value=0, max=229692), HTML(value='')))
# Skipping none vector at 227746
# Skipped 206

# %%
import re
import numpy as np
from scipy.stats import normaltest
import pingouin as pg

roots = [k for k in parent2children.keys() 
         if not any(k in children for children in parent2children.values())]
def tree_print(node, degree=0):
    print(("   " * degree) + node)
    if node in parent2children:
        for child in parent2children[node]:
            tree_print(child, degree + 1)
            
def filter_by_pattern(pairs, pattern):
    return [pair for pair in pairs if re.match(pattern, pair[1].LU.name)]
            
    
#for root in roots:
#    tree_print(root)
#    print()
#tree_print('Relation')

def f(frames):
    hue = []
    labels = []
    vectors = []
    for frame in frames:
        fvecs, anns = zip(*frame2pairs[frame])
        print(frame, len(fvecs))
        vectors += fvecs
        hue += [frame for i in range(len(fvecs))]
        if len(fvecs) > 0:
            labels += [frame]
            labels += [None for i in range(len(fvecs)-1)]
                
    #hue = [x.LU.name for x in annotations]
    vectors = torch.stack(vectors).numpy()
    print(vectors.shape)
    print(len(labels))
    print(len(hue))
    print(dir(hypertools.plot(np.array(vectors), '.', reduce='TSNE', hue=hue, labels=labels, ndims=3)))

f(['Telling', 'Suasion', 'Warning', 'Reveal_secret', 'Recording', 'Predicting', 'Complaining', 'Affirm_or_deny', 'Statement'])

#Statement
#   Affirm_or_deny
#   Complaining
#   Predicting
#   Reading_aloud
#   Recording
#   Reveal_secret
#   Telling
#      Suasion
#      Warning
# Out:
# Telling 632
# Suasion 79
# Warning 114
# Reveal_secret 700
# Recording 55
# Predicting 154
# Complaining 220
# Affirm_or_deny 172
# Statement 3696
# (5822, 768)
# 5822
# 5822
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-388e6082a0eb> in <module>
#      41     print(dir(hypertools.plot(np.array(vectors), '.', reduce='TSNE', hue=hue, labels=labels, ndims=3)))
#      42
# ---> 43 f(['Telling', 'Suasion', 'Warning', 'Reveal_secret', 'Recording', 'Predicting', 'Complaining', 'Affirm_or_deny', 'Statement'])
#      44
#      45 #Statement
#
# <ipython-input-58-388e6082a0eb> in f(frames)
#      39     print(len(labels))
#      40     print(len(hue))
# ---> 41     print(dir(hypertools.plot(np.array(vectors), '.', reduce='TSNE', hue=hue, labels=labels, ndims=3)))
#      42
#      43 f(['Telling', 'Suasion', 'Warning', 'Reveal_secret', 'Recording', 'Predicting', 'Complaining', 'Affirm_or_deny', 'Statement'])
#
# ~/.anaconda3/lib/python3.7/site-packages/hypertools/plot/plot.py in plot(x, fmt, marker, markers, linestyle, linestyles, color, colors, palette, group, hue, labels, legend, title, size, elev, azim, ndims, model, model_params, reduce, cluster, align, normalize, n_clusters, save_path, animate, duration, tail_duration, rotations, zoom, chemtrails, precog, bullettime, frame_rate, explore, show, transform, vectorizer, semantic, corpus, ax)
#     329         # reshape the data according to group
#     330         if n_clusters is None:
# --> 331             xform, labels = reshape_data(xform, hue, labels)
#     332         # interpolate lines if they are grouped
#     333         if is_line(fmt):
#
# ~/.anaconda3/lib/python3.7/site-packages/hypertools/_shared/helpers.py in reshape_data(x, hue, labels)
#     131         labels = [None]*len(hue)
#     132     for idx, (point, label) in enumerate(zip(hue, labels)):
# --> 133         x_reshaped[categories.index(point)].append(x_stacked[idx])
#     134         labels_reshaped[categories.index(point)].append(labels[idx])
#     135     return [np.vstack(i) for i in x_reshaped], labels_reshaped
#
# IndexError: index 4741 is out of bounds for axis 0 with size 4741

# %%
rs = [r for r in fn.frame_relations() if r.type.name == "Using"]
#for r in rs:
#    print(r)
#for k ,v in parent2children.items():
#    if 'Volubility' in v:
#        print(k)
